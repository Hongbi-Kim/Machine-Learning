# %% [markdown]
# # 1-1
# - 데이터 중 컬럼들의 결측값을 전부 제거 후 데이터를 처음부터 순서대로 70%를 추출하여 변수 중 'tax'의 사분위수 Q1값을 구하시오.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/3rd_boston_housing.csv')
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  pratio  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296    15.3
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242    17.8
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242    17.8
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222    18.7
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222    18.7
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...     ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273    21.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273    21.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273    21.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273    21.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273    21.0
#
#           b  lstat  medv
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   crim    506 non-null    float64
#  1   zn      506 non-null    float64
#  2   indus   506 non-null    float64
#  3   chas    506 non-null    int64
#  4   nox     506 non-null    float64
#  5   rm      506 non-null    float64
#  6   age     506 non-null    float64
#  7   dis     506 non-null    float64
#  8   rad     506 non-null    int64
#  9   tax     506 non-null    int64
#  10  pratio  506 non-null    float64
#  11  b       506 non-null    float64
#  12  lstat   506 non-null    float64
#  13  medv    506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df = df.dropna()

# %%
506*0.7
# Out:
# 354.2

# %%
df = df.head(355)

# %%
df.quantile(0.25)['tax']
# Out:
# 264.0

# %% [markdown]
# # 1-2
# - 2000년도 전체 입국자 평균보다 국내에 많이 입국한 국가의 수 산출

# %%
df = pd.read_csv('./data/3rd_tour.csv', encoding = 'cp949')
df
# Out:
#     year       중국       일본      대만      홍콩     필리핀  인도네시아      태국    베트남  \
# 0   1995   178359  1667203  130147  100407  163228  37723   73770  16720
# 1   1996   199604  1526559  114729   77958  178045  46570   74162  16750
# 2   1997   214244  1676434  104144   96650  187235  53204   62374  14102
# 3   1998   210662  1954416  108880  229072  165272  36486   49973  11561
# 4   1999   316639  2184121  110563  234087  198583  47019   63679  16121
# 5   2000   442794  2472054  127120  200874  248737  59085   87885  21483
# 6   2001   482227  2377321  129410  204959  210975  57288   73163  20399
# 7   2002   539466  2320837  136921  179299  215848  65093   74000  23574
# 8   2003   512768  1802542  194586  156358  216627  62744   78243  28244
# 9   2004   627264  2443070  304908  155058  213434  61506  102588  33738
# 10  2005   710243  2440139  351438  166206  222655  62294  112724  45455
# 11  2006   896969  2338921  338162  142835  248262  62869  128555  46077
# ...

# %%
total = df[df['year'] == 2000].sum().sum()-2000
total
# Out:
# 5044194

# %%
count = len(df.columns)-1
count
# Out:
# 57

# %%
mean = total / count
mean
# Out:
# 88494.63157894737

# %%
(df[df['year'] == 2000] > mean).sum().sum()
# Out:
# 7

# %% [markdown]
# # 1-3
# - 데이터셋의 컬럼 중 빈값 또는 결측치를 확인하여 결측치의 비율이 높은 변수명을 출력

# %%
df = pd.read_csv('./data/3rd_titanic.csv')
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Embarked
# ...

# %%
df.isnull().sum().idxmax()
# Out:
# 'Age'

# %% [markdown]
# # 2
# - 여행객 보험 데이터셋을 참조하여 여행객의 정보들을 기반으로 여행보험 상품 가입 여부를 예측하시오.
# - ID와 예측치를 csv 파일로 저장하여 제출

# %%
train = pd.read_csv('./data/3rd_TravelInsurancePrediction_train.csv')
test = pd.read_csv('./data/3rd_TravelInsurancePrediction_test.csv')

# %%
train.head()
# Out:
#    ID  Age               Employment Type GraduateOrNot  AnnualIncome  \
# 0   0   31             Government Sector           Yes        400000
# 1   1   31  Private Sector/Self Employed           Yes       1250000
# 2   2   34  Private Sector/Self Employed           Yes        500000
# 3   3   28  Private Sector/Self Employed           Yes        700000
# 4   4   28  Private Sector/Self Employed           Yes        700000
#
#    FamilyMembers  ChronicDiseases FrequentFlyer EverTravelledAbroad  \
# 0              6                1            No                  No
# 1              7                0            No                  No
# 2              4                1            No                  No
# 3              3                1            No                  No
# 4              8                1           Yes                  No
#
#    TravelInsurance
# 0                0
# 1                0
# 2                1
# 3                0
# 4                0

# %%
test.head()
# Out:
#      ID  Age               Employment Type GraduateOrNot  AnnualIncome  \
# 0  1501   28  Private Sector/Self Employed           Yes        800000
# 1  1502   28  Private Sector/Self Employed           Yes        750000
# 2  1503   29  Private Sector/Self Employed           Yes        500000
# 3  1504   34  Private Sector/Self Employed           Yes        850000
# 4  1505   27             Government Sector           Yes        500000
#
#    FamilyMembers  ChronicDiseases FrequentFlyer EverTravelledAbroad
# 0              4                0            No                  No
# 1              6                1            No                  No
# 2              4                0            No                  No
# 3              2                0            No                  No
# 4              4                0            No                  No

# %%
train.columns
# Out:
# Index(['ID', 'Age', 'Employment Type', 'GraduateOrNot', 'AnnualIncome',
#        'FamilyMembers', 'ChronicDiseases', 'FrequentFlyer',
#        'EverTravelledAbroad', 'TravelInsurance'],
#       dtype='object')

# %%
X = train[['Age', 'Employment Type', 'GraduateOrNot', 'AnnualIncome','FamilyMembers', 'ChronicDiseases', 
           'FrequentFlyer','EverTravelledAbroad']]
y = train[['TravelInsurance']]

# %%
X_num = X[['Age', 'AnnualIncome','FamilyMembers', 'ChronicDiseases']]
X_cat = X[['Employment Type', 'GraduateOrNot','FrequentFlyer','EverTravelledAbroad']]
X_cat = pd.get_dummies(X_cat)

# %%
test_num = test[['Age', 'AnnualIncome','FamilyMembers', 'ChronicDiseases']]
test_cat = test[['Employment Type', 'GraduateOrNot','FrequentFlyer','EverTravelledAbroad']]
test_cat = pd.get_dummies(test_cat)

# %%
X_cat, test_cat = X_cat.align(test_cat, join = 'inner',  axis = 1)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax = MinMaxScaler()
minmax.fit(X_num)

# %%
X_scaled = minmax.transform(X_num)
X_scaled
# Out:
# array([[0.6       , 0.06666667, 0.57142857, 1.        ],
#        [0.6       , 0.63333333, 0.71428571, 0.        ],
#        [0.9       , 0.13333333, 0.28571429, 1.        ],
#        ...,
#        [0.8       , 0.2       , 0.28571429, 0.        ],
#        [0.3       , 0.6       , 0.14285714, 0.        ],
#        [0.        , 0.96666667, 0.14285714, 0.        ]])

# %%
test_scaled = minmax.transform(test_num)
test_scaled
# Out:
# array([[0.3       , 0.33333333, 0.28571429, 0.        ],
#        [0.3       , 0.3       , 0.57142857, 1.        ],
#        [0.4       , 0.13333333, 0.28571429, 0.        ],
#        ...,
#        [0.3       , 0.56666667, 0.57142857, 1.        ],
#        [0.9       , 0.46666667, 0.57142857, 0.        ],
#        [0.9       , 0.13333333, 0.28571429, 0.        ]])

# %%
X_final = pd.concat([pd.DataFrame(X_scaled), X_cat], axis = 1)
X_final.head()
# Out:
#      0         1         2    3  Employment Type_Government Sector  \
# 0  0.6  0.066667  0.571429  1.0                                  1
# 1  0.6  0.633333  0.714286  0.0                                  0
# 2  0.9  0.133333  0.285714  1.0                                  0
# 3  0.3  0.266667  0.142857  1.0                                  0
# 4  0.3  0.266667  0.857143  1.0                                  0
#
#    Employment Type_Private Sector/Self Employed  GraduateOrNot_No  \
# 0                                             0                 0
# 1                                             1                 0
# 2                                             1                 0
# 3                                             1                 0
# 4                                             1                 0
#
#    GraduateOrNot_Yes  FrequentFlyer_No  FrequentFlyer_Yes  \
# 0                  1                 1                  0
# ...

# %%
test_final = pd.concat([pd.DataFrame(test_scaled), test_cat], axis = 1)
test_final.head()
# Out:
#      0         1         2    3  Employment Type_Government Sector  \
# 0  0.3  0.333333  0.285714  0.0                                  0
# 1  0.3  0.300000  0.571429  1.0                                  0
# 2  0.4  0.133333  0.285714  0.0                                  0
# 3  0.9  0.366667  0.000000  0.0                                  0
# 4  0.2  0.133333  0.285714  0.0                                  1
#
#    Employment Type_Private Sector/Self Employed  GraduateOrNot_No  \
# 0                                             1                 0
# 1                                             1                 0
# 2                                             1                 0
# 3                                             1                 0
# 4                                             0                 0
#
#    GraduateOrNot_Yes  FrequentFlyer_No  FrequentFlyer_Yes  \
# 0                  1                 1                  0
# ...

# %%
y = y['TravelInsurance']
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1496    0
# 1497    1
# 1498    0
# 1499    0
# 1500    1
# Name: TravelInsurance, Length: 1501, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(X_final, y)
# Out:
# LogisticRegression()

# %%
pred_test = model.predict_proba(test_final)
pred_test_prob = pd.DataFrame(pred_test[:, 1], columns = ['predict_prob'])
final_predict = pd.concat([test['ID'], pred_test_prob], axis = 1)

# %%
#final_predict.to_csv('20220603.csv', index = False)
